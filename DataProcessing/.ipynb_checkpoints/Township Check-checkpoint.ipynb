# %%
import numpy as np
import pandas as pd
import json

# %%
d = None
with open("admin_level_8.json") as json_data:
    d = json.load(json_data)

# %%
for ts in d["features"]:
    print(ts)
# Out:
# {u'name': u'\u1015\u102f\u1007\u103d\u1014\u103a\u1010\u1031\u102c\u1004\u103a', u'geometry': {u'type': u'MultiPolygon', u'coordinates': [[[[96.1849335, 16.774998200000002], [96.18393139999999, 16.7730002], [96.1838952, 16.772923], [96.1834034, 16.773119599999998], [96.18243889999998, 16.7735052], [96.18235429999999, 16.773538999999996], [96.1818586, 16.773737099999998], [96.18112300000001, 16.7740312], [96.1810174, 16.7740727], [96.18078589999999, 16.7739176], [96.180609, 16.7737944], [96.18047309999999, 16.7737147], [96.18030199999998, 16.773636399999997], [96.18008819999999, 16.773602899999997], [96.1792176, 16.7736257], [96.17810679999998, 16.773656799999998], [96.177053, 16.7736952], [96.17658399999999, 16.773710899999998], [96.17613879999998, 16.7737259], [96.17594659999999, 16.773732599999995], [96.17535859999998, 16.7737655], [96.17478049999998, 16.773790299999998], [96.17426920000001, 16.7738075], [96.17390859999999, 16.773818400000003], [96.17372849999998, 16.77382590000000
# ...
